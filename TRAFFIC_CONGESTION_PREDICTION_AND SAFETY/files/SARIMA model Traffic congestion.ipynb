# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('traffic.csv')
df
# Out:
#                   DateTime  Junction  Vehicles           ID
# 0      2015-11-01 00:00:00         1        15  20151101001
# 1      2015-11-01 01:00:00         1        13  20151101011
# 2      2015-11-01 02:00:00         1        10  20151101021
# 3      2015-11-01 03:00:00         1         7  20151101031
# 4      2015-11-01 04:00:00         1         9  20151101041
# ...                    ...       ...       ...          ...
# 48115  2017-06-30 19:00:00         4        11  20170630194
# 48116  2017-06-30 20:00:00         4        30  20170630204
# 48117  2017-06-30 21:00:00         4        16  20170630214
# 48118  2017-06-30 22:00:00         4        22  20170630224
# 48119  2017-06-30 23:00:00         4        12  20170630234
#
# [48120 rows x 4 columns]

# %%
df['DateTime'] = pd.to_datetime(df['DateTime'])
df
# Out:
#                  DateTime  Junction  Vehicles           ID
# 0     2015-11-01 00:00:00         1        15  20151101001
# 1     2015-11-01 01:00:00         1        13  20151101011
# 2     2015-11-01 02:00:00         1        10  20151101021
# 3     2015-11-01 03:00:00         1         7  20151101031
# 4     2015-11-01 04:00:00         1         9  20151101041
# ...                   ...       ...       ...          ...
# 48115 2017-06-30 19:00:00         4        11  20170630194
# 48116 2017-06-30 20:00:00         4        30  20170630204
# 48117 2017-06-30 21:00:00         4        16  20170630214
# 48118 2017-06-30 22:00:00         4        22  20170630224
# 48119 2017-06-30 23:00:00         4        12  20170630234
#
# [48120 rows x 4 columns]

# %%
df['Year'] = df['DateTime'].dt.year
df['Month'] = df['DateTime'].dt.month
df['Date_no'] = df['DateTime'].dt.date
df['Hour'] = df['DateTime'].dt.hour
df['Day'] = df['DateTime'].dt.day
df
# Out:
#                  DateTime  Junction  Vehicles           ID  Year  Month  \
# 0     2015-11-01 00:00:00         1        15  20151101001  2015     11
# 1     2015-11-01 01:00:00         1        13  20151101011  2015     11
# 2     2015-11-01 02:00:00         1        10  20151101021  2015     11
# 3     2015-11-01 03:00:00         1         7  20151101031  2015     11
# 4     2015-11-01 04:00:00         1         9  20151101041  2015     11
# ...                   ...       ...       ...          ...   ...    ...
# 48115 2017-06-30 19:00:00         4        11  20170630194  2017      6
# 48116 2017-06-30 20:00:00         4        30  20170630204  2017      6
# 48117 2017-06-30 21:00:00         4        16  20170630214  2017      6
# 48118 2017-06-30 22:00:00         4        22  20170630224  2017      6
# 48119 2017-06-30 23:00:00         4        12  20170630234  2017      6
#
#           Date_no  Hour  Day
# 0      2015-11-01     0    1
# 1      2015-11-01     1    1
# 2      2015-11-01     2    1
# 3      2015-11-01     3    1
# 4      2015-11-01     4    1
# ...           ...   ...  ...
# 48115  2017-06-30    19   30
# 48116  2017-06-30    20   30
# 48117  2017-06-30    21   30
# 48118  2017-06-30    22   30
# 48119  2017-06-30    23   30
#
# [48120 rows x 9 columns]

# %%
df.set_index('DateTime',inplace=True)
df
# Out:
#                      Junction  Vehicles           ID  Year  Month     Date_no  \
# DateTime
# 2015-11-01 00:00:00         1        15  20151101001  2015     11  2015-11-01
# 2015-11-01 01:00:00         1        13  20151101011  2015     11  2015-11-01
# 2015-11-01 02:00:00         1        10  20151101021  2015     11  2015-11-01
# 2015-11-01 03:00:00         1         7  20151101031  2015     11  2015-11-01
# 2015-11-01 04:00:00         1         9  20151101041  2015     11  2015-11-01
# ...                       ...       ...          ...   ...    ...         ...
# 2017-06-30 19:00:00         4        11  20170630194  2017      6  2017-06-30
# 2017-06-30 20:00:00         4        30  20170630204  2017      6  2017-06-30
# 2017-06-30 21:00:00         4        16  20170630214  2017      6  2017-06-30
# 2017-06-30 22:00:00         4        22  20170630224  2017      6  2017-06-30
# 2017-06-30 23:00:00         4        12  20170630234  2017      6  2017-06-30
#
#                      Hour  Day
# DateTime
# 2015-11-01 00:00:00     0    1
# 2015-11-01 01:00:00     1    1
# 2015-11-01 02:00:00     2    1
# 2015-11-01 03:00:00     3    1
# 2015-11-01 04:00:00     4    1
# ...                   ...  ...
# 2017-06-30 19:00:00    19   30
# 2017-06-30 20:00:00    20   30
# 2017-06-30 21:00:00    21   30
# 2017-06-30 22:00:00    22   30
# 2017-06-30 23:00:00    23   30
#
# [48120 rows x 8 columns]

# %%
#df = pd.get_dummies(df, columns=['Date_no'], drop_first=True)
#df

# %%
time_features = df.iloc[:,4:]
time_features
# Out:
#                      Month     Date_no  Hour  Day
# DateTime
# 2015-11-01 00:00:00     11  2015-11-01     0    1
# 2015-11-01 01:00:00     11  2015-11-01     1    1
# 2015-11-01 02:00:00     11  2015-11-01     2    1
# 2015-11-01 03:00:00     11  2015-11-01     3    1
# 2015-11-01 04:00:00     11  2015-11-01     4    1
# ...                    ...         ...   ...  ...
# 2017-06-30 19:00:00      6  2017-06-30    19   30
# 2017-06-30 20:00:00      6  2017-06-30    20   30
# 2017-06-30 21:00:00      6  2017-06-30    21   30
# 2017-06-30 22:00:00      6  2017-06-30    22   30
# 2017-06-30 23:00:00      6  2017-06-30    23   30
#
# [48120 rows x 4 columns]

# %%
for i in time_features:
    plt.figure(figsize=(13,3))
    ax=sns.lineplot(x=df[i],y="Vehicles",data=df, hue="Junction" )
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(10,9))
cor = df.corr()
sns.heatmap(cor,annot=True,square=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df,x=df['Date_no'],y=df['Vehicles'])
# Out:
# <AxesSubplot:xlabel='Date_no', ylabel='Vehicles'>

# %%
#identifying if our data is stationary or not through mean and standard deviation as parameters.
df['rollMean']= df.Vehicles.rolling(window=12).mean()
df['rollStd']= df.Vehicles.rolling(window=12).std()

plt.figure(figsize=(10,5))
sns.lineplot(data=df,x=df['Date_no'],y=df['Vehicles'])
sns.lineplot(data=df,x=df['Date_no'],y=df.rollMean)
sns.lineplot(data=df,x=df['Date_no'],y=df.rollStd)
# Out:
# <AxesSubplot:xlabel='Date_no', ylabel='Vehicles'>

# %%
#checking stationarity using ADF
from statsmodels.tsa.stattools import adfuller
adf_result = adfuller(df['Vehicles'],autolag='AIC')
adf_statistic = adf_result[0]
adf_p_value = adf_result[1]
adf_critical_values = adf_result[4]

print("ADF p-value:", adf_p_value)
print("ADF Statistic:", adf_statistic)
print("ADF Critical Values:", adf_critical_values)
# Out:
# ADF p-value: 3.8510601999154877e-11
# ADF Statistic: -7.518278111935725
# ADF Critical Values: {'1%': -3.430486066940443, '5%': -2.8616001387397922, '10%': -2.566802009871527}

# %%
import statsmodels.api as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX
p, d, q = 1, 1, 1  
P, D, Q, s = 1, 1, 1, 24 

model = SARIMAX(df['Vehicles'], order=(p, d, q), seasonal_order=(P, D, Q, s))
results = model.fit()

forecast_steps = 10
forecast = results.get_forecast(steps=forecast_steps)

forecast_values = forecast.predicted_mean
forecast_conf_int = forecast.conf_int()

plt.figure(figsize=(12, 10))
plt.plot(df['Year'], df['Vehicles'], label='Observed', color='green')
plt.plot(forecast_values.index, forecast_values.values, label='Forecast', color='red')
plt.fill_between(
    forecast_conf_int.index,
    forecast_conf_int.iloc[:, 0],
    forecast_conf_int.iloc[:, 1],
    color='black',
    alpha=0.5,
)
plt.xlabel('Date and Time')
plt.ylabel('Vehicles')
plt.legend()
plt.title('SARIMA Forecast')
plt.show()

# %%
print(forecast_values)
# Out:
# 48120    10.718194
# 48121     9.575010
# 48122     8.767587
# 48123     8.570400
# 48124     8.046897
# Name: predicted_mean, dtype: float64
